# %%
import pandas as pd
df = pd.read_csv('kevin_murtha.csv')
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
import altair as alt
chart = alt.Chart(df)
alt.Chart(df).mark_point().encode(
    x='base_salary',
    y='average(total_ot_paid)'
)
# Out:
# alt.Chart(...)

# %%
from plotnine import *

# %%
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns

sns.pairplot(df)

# %% [markdown]
# ### Important notes from the data dictionary
#
# #### Base salary:
# The amount the job pays (not necessarily what was earned) and not including any other pay (differentials, lump sums, uniform allowance, meal allowance, retroactive pay increases, settlement amounts, etc) or overtime!
#
# #### Regular Gross Paid:
# The actual base salary during reporting period, which is the portion of the person’s annual salary paid before deductions are withheld. This does not include overtime pay or other compensation and does not reflect the after tax amount or net pay. Total gross pay is calculated by adding columns L, N and O.
#
# #### Leave status:
# Status of employee as of the close of the relevant fiscal year: Active, Ceased, or On Leave

# %% [markdown]
# `From here on, for the purpose of this pitch, we'll only consider those currently on active duty`

# %%
df.query('leave_status_as_of_june_30== "ACTIVE"').sort_values(by='base_salary', ascending = False).head(10)
# Out:
#    fiscal_year  payroll_number        agency_name last_name first_name  \
# 5         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 6         2019           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 4         2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 1         2016             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 2         2015             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 3         2014             NaN  Police Department    MURTHA      KEVIN
#
#    mid_init agency_start_date work_location_borough  \
# 5       NaN        04/30/1995              BROOKLYN
# 6       NaN        04/30/1995              BROOKLYN
# 4       NaN        04/30/1995              BROOKLYN
# 1       NaN        04/30/1995              BROOKLYN
# 2       NaN        04/30/1995             MANHATTAN
# 3       NaN        04/30/1995                   NaN
#
#                    title_description leave_status_as_of_june_30  base_salary  \
# 5  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 6  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 4  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   134,067.00
# 1  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   122,750.00
# 2  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   119,388.00
# 3  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   113,554.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 5  per Annum       2,045.72          134,294.80    536.33      62,473.98
# 6  per Annum       2,040.00          137,710.56    387.87      57,280.57
# 4  per Annum       2,051.43          132,640.94    433.70      50,799.80
# 1  per Annum       2,091.42          119,762.52    453.53      43,342.25
# 2  per Annum       2,085.72          121,296.29    451.27      47,199.15
# 3  per Annum       2,085.72          112,891.25    419.93      40,223.91
#
#    total_other_pay
# 5        27,815.30
# 6        25,084.00
# 4        28,006.50
# 1        24,975.58
# 2        21,177.23
# 3        20,751.22

# %% [markdown]
# #### Observation
# 📚 The highest earning ranks, by base salary are: Commissioners, deputy commissioners and department chiefs.

# %% [markdown]
# ` Question to ask domain expert `
#
# 🚨 How to find deductions to calculate net, or take-home pay. For now, we're assuming the take home pay is regular gross plus overtime and other pay. Let's calculate that.

# %%
df['total_pay'] = df['regular_gross_paid'] + df['total_ot_paid'] + df['total_other_pay']

# %%
df.query('leave_status_as_of_june_30== "ACTIVE"').sort_values(by='total_pay', ascending = False).head(10)
# Out:
#    fiscal_year  payroll_number        agency_name last_name first_name  \
# 5         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 6         2019           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 4         2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 2         2015             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 1         2016             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 3         2014             NaN  Police Department    MURTHA      KEVIN
#
#    mid_init agency_start_date work_location_borough  \
# 5       NaN        04/30/1995              BROOKLYN
# 6       NaN        04/30/1995              BROOKLYN
# 4       NaN        04/30/1995              BROOKLYN
# 2       NaN        04/30/1995             MANHATTAN
# 1       NaN        04/30/1995              BROOKLYN
# 3       NaN        04/30/1995                   NaN
#
#                    title_description leave_status_as_of_june_30  base_salary  \
# 5  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 6  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 4  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   134,067.00
# 2  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   119,388.00
# 1  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   122,750.00
# 3  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   113,554.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 5  per Annum       2,045.72          134,294.80    536.33      62,473.98
# 6  per Annum       2,040.00          137,710.56    387.87      57,280.57
# 4  per Annum       2,051.43          132,640.94    433.70      50,799.80
# 2  per Annum       2,085.72          121,296.29    451.27      47,199.15
# 1  per Annum       2,091.42          119,762.52    453.53      43,342.25
# 3  per Annum       2,085.72          112,891.25    419.93      40,223.91
#
#    total_other_pay  total_pay
# 5        27,815.30 224,584.08
# 6        25,084.00 220,075.13
# 4        28,006.50 211,447.24
# 2        21,177.23 189,672.67
# 1        24,975.58 188,080.35
# 3        20,751.22 173,866.38

# %%
model = smf.ols('total_pay ~ total_ot_paid', data=df.query('leave_status_as_of_june_30== "ACTIVE"'))
results = model.fit()
results.summary()
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              total_pay   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     48.67
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):            0.00222
# Time:                        15:20:04   Log-Likelihood:                -59.744
# No. Observations:                   6   AIC:                             123.5
# Df Residuals:                       4   BIC:                             123.1
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      8.527e+04   1.68e+04      5.068      0.007    3.86e+04    1.32e+05
# total_ot_paid     2.3102      0.331      6.976      0.002       1.391       3.230
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.029
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.594
# Skew:                           0.518   Prob(JB):                        0.743
# Kurtosis:                       1.859   Cond. No.                     3.35e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### 📚 Observation
# About 54% variation in total pay is explained by total over time paid. Not much of a difference observed when non active duty officials are included.

# %%
model = smf.ols('total_pay ~ total_ot_paid', data=df)
results = model.fit()
results.summary()
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              total_pay   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     39.04
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):            0.00154
# Time:                        15:20:28   Log-Likelihood:                -75.539
# No. Observations:                   7   AIC:                             155.1
# Df Residuals:                       5   BIC:                             155.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       1.59e+05   1.02e+04     15.569      0.000    1.33e+05    1.85e+05
# total_ot_paid     0.8264      0.132      6.249      0.002       0.486       1.166
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.983
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.621
# Skew:                          -0.064   Prob(JB):                        0.733
# Kurtosis:                       1.546   Cond. No.                     1.50e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# `Ignoring the leave status for a second to look at all employees`

# %%
to_plot = df[['pay_basis', 'regular_hours','total_pay','ot_hours']]
# to_plot = to_plot.query('pay_basis=="per Annum"')
to_plot = (to_plot.melt(id_vars = ['ot_hours', 'pay_basis']).dropna().query('ot_hours > 10'))

(
    ggplot(to_plot, aes(x='value', y='ot_hours')) + 
        geom_point() +
        facet_wrap('pay_basis', scales='free_x') + 
        theme(figure_size=(16,5))
)
# Out:
# <ggplot: (395266454)>

# %%
df.query('pay_basis == "per Annum"').sort_values(by='ot_hours', ascending = False).head(5)
# Out:
#    fiscal_year  payroll_number        agency_name last_name first_name  \
# 0         2020           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 5         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 1         2016             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 2         2015             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 4         2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
#
#    mid_init agency_start_date work_location_borough  \
# 0       NaN        04/30/1995             MANHATTAN
# 5       NaN        04/30/1995              BROOKLYN
# 1       NaN        04/30/1995              BROOKLYN
# 2       NaN        04/30/1995             MANHATTAN
# 4       NaN        04/30/1995              BROOKLYN
#
#                    title_description leave_status_as_of_june_30  base_salary  \
# 0  LIEUTENANT D/A SPECIAL ASSIGNMENT                     CEASED   141,196.00
# 5  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 1  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   122,750.00
# 2  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   119,388.00
# 4  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   134,067.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 0  per Annum         665.18           48,008.86  2,451.57     162,000.47
# 5  per Annum       2,045.72          134,294.80    536.33      62,473.98
# 1  per Annum       2,091.42          119,762.52    453.53      43,342.25
# 2  per Annum       2,085.72          121,296.29    451.27      47,199.15
# 4  per Annum       2,051.43          132,640.94    433.70      50,799.80
#
#    total_other_pay  total_pay
# 0        78,132.88 288,142.21
# 5        27,815.30 224,584.08
# 1        24,975.58 188,080.35
# 2        21,177.23 189,672.67
# 4        28,006.50 211,447.24

# %%
df.sort_values(by='ot_hours', ascending = False).head(5)
# Out:
#    fiscal_year  payroll_number        agency_name last_name first_name  \
# 0         2020           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 5         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 1         2016             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 2         2015             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 4         2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
#
#    mid_init agency_start_date work_location_borough  \
# 0       NaN        04/30/1995             MANHATTAN
# 5       NaN        04/30/1995              BROOKLYN
# 1       NaN        04/30/1995              BROOKLYN
# 2       NaN        04/30/1995             MANHATTAN
# 4       NaN        04/30/1995              BROOKLYN
#
#                    title_description leave_status_as_of_june_30  base_salary  \
# 0  LIEUTENANT D/A SPECIAL ASSIGNMENT                     CEASED   141,196.00
# 5  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 1  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   122,750.00
# 2  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   119,388.00
# 4  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   134,067.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 0  per Annum         665.18           48,008.86  2,451.57     162,000.47
# 5  per Annum       2,045.72          134,294.80    536.33      62,473.98
# 1  per Annum       2,091.42          119,762.52    453.53      43,342.25
# 2  per Annum       2,085.72          121,296.29    451.27      47,199.15
# 4  per Annum       2,051.43          132,640.94    433.70      50,799.80
#
#    total_other_pay  total_pay
# 0        78,132.88 288,142.21
# 5        27,815.30 224,584.08
# 1        24,975.58 188,080.35
# 2        21,177.23 189,672.67
# 4        28,006.50 211,447.24

# %%
df['hours_diff'] = df['ot_hours'] - df['regular_hours']

# %%
model = smf.ols('total_ot_paid ~ regular_gross_paid', data=df)
results = model.fit()
results.summary()
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          total_ot_paid   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     20.02
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):            0.00656
# Time:                        15:21:53   Log-Likelihood:                -78.432
# No. Observations:                   7   AIC:                             160.9
# Df Residuals:                       5   BIC:                             160.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           2.091e+05   3.29e+04      6.352      0.001    1.25e+05    2.94e+05
# regular_gross_paid    -1.2406      0.277     -4.474      0.007      -1.953      -0.528
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.191
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.721
# Skew:                          -0.350   Prob(JB):                        0.697
# Kurtosis:                       1.592   Cond. No.                     4.92e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.92e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df.sort_values(by='total_ot_paid', ascending = False).head(10)
# Out:
#    fiscal_year  payroll_number        agency_name last_name first_name  \
# 0         2020           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 5         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 6         2019           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 4         2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 2         2015             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 1         2016             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 3         2014             NaN  Police Department    MURTHA      KEVIN
#
#    mid_init agency_start_date work_location_borough  \
# 0       NaN        04/30/1995             MANHATTAN
# 5       NaN        04/30/1995              BROOKLYN
# 6       NaN        04/30/1995              BROOKLYN
# 4       NaN        04/30/1995              BROOKLYN
# 2       NaN        04/30/1995             MANHATTAN
# 1       NaN        04/30/1995              BROOKLYN
# 3       NaN        04/30/1995                   NaN
#
#                    title_description leave_status_as_of_june_30  base_salary  \
# 0  LIEUTENANT D/A SPECIAL ASSIGNMENT                     CEASED   141,196.00
# 5  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 6  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 4  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   134,067.00
# 2  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   119,388.00
# 1  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   122,750.00
# 3  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   113,554.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 0  per Annum         665.18           48,008.86  2,451.57     162,000.47
# 5  per Annum       2,045.72          134,294.80    536.33      62,473.98
# 6  per Annum       2,040.00          137,710.56    387.87      57,280.57
# 4  per Annum       2,051.43          132,640.94    433.70      50,799.80
# 2  per Annum       2,085.72          121,296.29    451.27      47,199.15
# 1  per Annum       2,091.42          119,762.52    453.53      43,342.25
# 3  per Annum       2,085.72          112,891.25    419.93      40,223.91
#
#    total_other_pay  total_pay  hours_diff
# 0        78,132.88 288,142.21    1,786.39
# 5        27,815.30 224,584.08   -1,509.39
# 6        25,084.00 220,075.13   -1,652.13
# 4        28,006.50 211,447.24   -1,617.73
# 2        21,177.23 189,672.67   -1,634.45
# 1        24,975.58 188,080.35   -1,637.89
# 3        20,751.22 173,866.38   -1,665.79

# %%
df.query('last_name == "MURTHA"').query('first_name == "KEVIN"')
# Out:
#    fiscal_year  payroll_number        agency_name last_name first_name  \
# 0         2020           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 1         2016             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 2         2015             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 3         2014             NaN  Police Department    MURTHA      KEVIN
# 4         2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 5         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 6         2019           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
#
#    mid_init agency_start_date work_location_borough  \
# 0       NaN        04/30/1995             MANHATTAN
# 1       NaN        04/30/1995              BROOKLYN
# 2       NaN        04/30/1995             MANHATTAN
# 3       NaN        04/30/1995                   NaN
# 4       NaN        04/30/1995              BROOKLYN
# 5       NaN        04/30/1995              BROOKLYN
# 6       NaN        04/30/1995              BROOKLYN
#
#                    title_description leave_status_as_of_june_30  base_salary  \
# 0  LIEUTENANT D/A SPECIAL ASSIGNMENT                     CEASED   141,196.00
# 1  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   122,750.00
# 2  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   119,388.00
# 3  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   113,554.00
# 4  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   134,067.00
# 5  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
# 6  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE   138,089.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 0  per Annum         665.18           48,008.86  2,451.57     162,000.47
# 1  per Annum       2,091.42          119,762.52    453.53      43,342.25
# 2  per Annum       2,085.72          121,296.29    451.27      47,199.15
# 3  per Annum       2,085.72          112,891.25    419.93      40,223.91
# 4  per Annum       2,051.43          132,640.94    433.70      50,799.80
# 5  per Annum       2,045.72          134,294.80    536.33      62,473.98
# 6  per Annum       2,040.00          137,710.56    387.87      57,280.57
#
#    total_other_pay  total_pay  hours_diff
# 0        78,132.88 288,142.21    1,786.39
# 1        24,975.58 188,080.35   -1,637.89
# 2        21,177.23 189,672.67   -1,634.45
# 3        20,751.22 173,866.38   -1,665.79
# 4        28,006.50 211,447.24   -1,617.73
# 5        27,815.30 224,584.08   -1,509.39
# 6        25,084.00 220,075.13   -1,652.13

# %%
total_gross = df.regular_gross_paid.sum()
total_ot = df.total_ot_paid.sum()

# %%
df.ot_hours.mean().round()
# Out:
# 733.0

# %%
kevin_df = pd.read_csv('kevin_murtha.csv')
kevin_df.columns = kevin_df.columns.str.replace(" ", "_")
kevin_df.columns = kevin_df.columns.str.replace("-", "_")
kevin_df.columns = kevin_df.columns.str.lower()

# %%
kevin_df.ot_hours.mean().round(2)
# Out:
# 733.46

# %%
kevin_df.regular_hours.mean().round(2)
# Out:
# 1866.46

# %% [markdown]
# A lot more possibilities here, but essentially, the idea is to look at how one cop Kevin Murtha made more than anyone else (and that too by an almost $44,000 difference with the next highest paid employee) in overtime. And, after he made so much money, did he retire or was he laid off? Who is Kevin Murtha?

# %% [markdown]
# # Reporting plan ~ tentative
#
# `Questions to ask:`
#
# 1. Is it normal for one cop to make so much more than others?
# 2. What factors could potentially lead to him making so much more?
# 3. For some PDs, retirement salary is based on final year's pay — did Kevin Murtha then game the system to make extra money in overtime to be able to make higher in retirement?
